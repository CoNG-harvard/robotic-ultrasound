# %%
import cv2
from matplotlib import pyplot as plt

# %%
vid = cv2.VideoCapture('/dev/video10')

# %%
cv2.VideoCapture.release(vid)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-a60c7f290d13> in <module>
# ----> 1 cv2.VideoCapture.release(vid)
#
# NameError: name 'cv2' is not defined

# %%
ret, frame = vid.read()		
plt.imshow(frame)
