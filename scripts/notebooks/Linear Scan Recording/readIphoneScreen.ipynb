# %%
import cv2
from matplotlib import pyplot as plt

# %%
vid = cv2.VideoCapture('/dev/video13')

# %%
ret, frame = vid.read()		
plt.imshow(frame)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /home/naliseas-workstation/Desktop/robotic-ultrasound/scripts/notebooks/Linear Scan Recording/readIphoneScreen.ipynb Cell 3 line 2
#       <a href='vscode-notebook-cell:/home/naliseas-workstation/Desktop/robotic-ultrasound/scripts/notebooks/Linear%20Scan%20Recording/readIphoneScreen.ipynb#W3sZmlsZQ%3D%3D?line=0'>1</a> ret, frame = vid.read()
# ----> <a href='vscode-notebook-cell:/home/naliseas-workstation/Desktop/robotic-ultrasound/scripts/notebooks/Linear%20Scan%20Recording/readIphoneScreen.ipynb#W3sZmlsZQ%3D%3D?line=1'>2</a> plt.imshow(frame)
#
# File ~/anaconda3/envs/robotic_ultrasound/lib/python3.10/site-packages/matplotlib/pyplot.py:3346, in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, interpolation_stage, filternorm, filterrad, resample, url, data, **kwargs)
# ...

# %%
frame
